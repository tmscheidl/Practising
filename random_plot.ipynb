# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
randomNumber1 = np.random.rand(10)
randomNumber2 = np.random.rand(10)
randomNumber3 = np.random.rand(10)

# %%
print(randomNumber)
# Out:
# [0.56355037 0.49120197 0.79350159 0.4578483  0.12819139 0.2957045
#  0.00475298 0.5010465  0.65671028 0.12103792]

# %%
style.use('ggplot')
plt.plot(randomNumber1, 'g', label = 'line one', linestyle = ':', linewidth= 2, alpha =.8)
plt.plot(randomNumber2, 'b', label = 'line two', linestyle = '-.', linewidth= 2, alpha =.8)
plt.plot(randomNumber3, 'r', label = 'line three', linestyle = '--', linewidth= 2, alpha =.8)

plt.xlabel('Range')
plt.ylabel('Numbers')
plt.title('First Plot')
plt.legend()
plt.show()
